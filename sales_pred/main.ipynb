# %%
import pandas as pd
pd.set_option('display.max_columns', 25)

# %%
df = pd.read_csv('sales_data_sample.csv', sep=',', nrows=1000, encoding='latin1')

# %%
df.shape
# Out:
# (1000, 25)

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#          ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0   2/24/2003 0:00  Shipped       1         2     2003  Motorcycles    95
# 1    5/7/2003 0:00  Shipped       2         5     2003  Motorcycles    95
# 2    7/1/2003 0:00  Shipped       3         7     2003  Motorcycles    95
# 3   8/25/2003 0:00  Shipped       3         8     2003  Motorcycles    95
# 4  10/10/2003 0:00  Shipped       4        10     2003  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# 1    S10_1678        Reims Collectables        26.47.1555
# 2    S10_1678           Lyon Souveniers  +33 1 46 62 7555
# 3    S10_1678         Toys4GrownUps.com        6265557265
# 4    S10_1678  Corporate Gift Ideas Co.        6505551386
#
#                     ADDRESSLINE1 ADDRESSLINE2           CITY STATE POSTALCODE  \
# 0        897 Long Airport Avenue          NaN            NYC    NY      10022
# 1             59 rue de l'Abbaye          NaN          Reims   NaN      51100
# 2  27 rue du Colonel Pierre Avia          NaN          Paris   NaN      75508
# 3             78934 Hillside Dr.          NaN       Pasadena    CA      90003
# 4                7734 Strong St.          NaN  San Francisco    CA        NaN
#
#   COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0     USA       NaN              Yu             Kwai    Small
# 1  France      EMEA         Henriot             Paul    Small
# 2  France      EMEA        Da Cunha           Daniel   Medium
# 3     USA       NaN           Young            Julie   Medium
# 4     USA       NaN           Brown            Julie   Medium

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 25 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       1000 non-null   int64
#  1   QUANTITYORDERED   1000 non-null   int64
#  2   PRICEEACH         1000 non-null   float64
#  3   ORDERLINENUMBER   1000 non-null   int64
#  4   SALES             1000 non-null   float64
#  5   ORDERDATE         1000 non-null   object
#  6   STATUS            1000 non-null   object
#  7   QTR_ID            1000 non-null   int64
#  8   MONTH_ID          1000 non-null   int64
#  9   YEAR_ID           1000 non-null   int64
#  10  PRODUCTLINE       1000 non-null   object
#  11  MSRP              1000 non-null   int64
#  12  PRODUCTCODE       1000 non-null   object
#  13  CUSTOMERNAME      1000 non-null   object
#  14  PHONE             1000 non-null   object
#  15  ADDRESSLINE1      1000 non-null   object
#  16  ADDRESSLINE2      111 non-null    object
#  17  CITY              1000 non-null   object
#  18  STATE             493 non-null    object
#  19  POSTALCODE        959 non-null    object
#  20  COUNTRY           1000 non-null   object
#  21  TERRITORY         605 non-null    object
#  22  CONTACTLASTNAME   1000 non-null   object
#  23  CONTACTFIRSTNAME  1000 non-null   object
#  24  DEALSIZE          1000 non-null   object
# dtypes: float64(2), int64(7), object(16)
# memory usage: 195.4+ KB

# %%
df['ORDERDATE'] = pd.to_datetime(df['ORDERDATE'])
df['YEAR_ID'] = pd.to_datetime(df['YEAR_ID'])
df['YEAR_ID'] = df['YEAR_ID'].dt.year

# %%
df['ORDERDATE']
# Out:
# 0     2003-02-24
# 1     2003-05-07
# 2     2003-07-01
# 3     2003-08-25
# 4     2003-10-10
#          ...
# 995   2003-11-14
# 996   2003-11-26
# 997   2004-01-02
# 998   2004-02-18
# 999   2004-03-20
# Name: ORDERDATE, Length: 1000, dtype: datetime64[ns]

# %%
df.isna().sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# YEAR_ID               0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# PHONE                 0
# ADDRESSLINE1          0
# ADDRESSLINE2        889
# CITY                  0
# STATE               507
# POSTALCODE           41
# COUNTRY               0
# TERRITORY           395
# CONTACTLASTNAME       0
# CONTACTFIRSTNAME      0
# DEALSIZE              0
# dtype: int64

# %%
df.drop('ADDRESSLINE2', axis=1, inplace=True)
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  YEAR_ID  PRODUCTLINE  MSRP  \
# 0 2003-02-24  Shipped       1         2     1970  Motorcycles    95
# 1 2003-05-07  Shipped       2         5     1970  Motorcycles    95
# 2 2003-07-01  Shipped       3         7     1970  Motorcycles    95
# 3 2003-08-25  Shipped       3         8     1970  Motorcycles    95
# 4 2003-10-10  Shipped       4        10     1970  Motorcycles    95
#
#   PRODUCTCODE              CUSTOMERNAME             PHONE  \
# 0    S10_1678         Land of Toys Inc.        2125557818
# 1    S10_1678        Reims Collectables        26.47.1555
# 2    S10_1678           Lyon Souveniers  +33 1 46 62 7555
# 3    S10_1678         Toys4GrownUps.com        6265557265
# 4    S10_1678  Corporate Gift Ideas Co.        6505551386
#
#                     ADDRESSLINE1           CITY STATE POSTALCODE COUNTRY  \
# 0        897 Long Airport Avenue            NYC    NY      10022     USA
# 1             59 rue de l'Abbaye          Reims   NaN      51100  France
# 2  27 rue du Colonel Pierre Avia          Paris   NaN      75508  France
# 3             78934 Hillside Dr.       Pasadena    CA      90003     USA
# 4                7734 Strong St.  San Francisco    CA        NaN     USA
#
#   TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE
# 0       NaN              Yu             Kwai    Small
# 1      EMEA         Henriot             Paul    Small
# 2      EMEA        Da Cunha           Daniel   Medium
# 3       NaN           Young            Julie   Medium
# 4       NaN           Brown            Julie   Medium

# %%
import matplotlib.pyplot as plt
df['year'] = df['ORDERDATE'].dt.year
# df_sell_per_year = df.groupby('YEAR_ID')['SALES'].sum()

# %%
df_sell_per_year = df.groupby('year')['SALES'].sum()
df_sell_per_year= df_sell_per_year.reset_index()
df_sell_per_year.columns = ['year', 'SALES']

# %%
# df2 = pd.DataFrame(df_sell_per_year)

# %%
df_sell_per_year
# Out:
#    year       SALES
# 0  2003  1631144.23
# 1  2004  1906334.70
# 2  2005   686854.71

# %%
df_sell_per_year['year'] = pd.to_datetime(df_sell_per_year['year'], format='%Y')

# %%
fig, ax = plt.subplots()
ax.plot(df_sell_per_year['year'], df_sell_per_year['SALES'], linestyle='-', marker='o', color='r')
ax.set_ylabel('Total Sales - sales*10**6')
plt.xticks(rotation=45);

# %%
df.drop('YEAR_ID', axis=1, inplace=True)

# %%
df.columns
# Out:
# Index(['ORDERNUMBER', 'QUANTITYORDERED', 'PRICEEACH', 'ORDERLINENUMBER',
#        'SALES', 'ORDERDATE', 'STATUS', 'QTR_ID', 'MONTH_ID', 'PRODUCTLINE',
#        'MSRP', 'PRODUCTCODE', 'CUSTOMERNAME', 'PHONE', 'ADDRESSLINE1', 'CITY',
#        'STATE', 'POSTALCODE', 'COUNTRY', 'TERRITORY', 'CONTACTLASTNAME',
#        'CONTACTFIRSTNAME', 'DEALSIZE', 'year'],
#       dtype='object')

# %%
df['COUNTRY'].nunique()
# Out:
# 19

# %%
sell_per_country = df.groupby('COUNTRY')['SALES'].sum()
sell_per_country = sell_per_country.reset_index()
sell_per_country.columns = ['COUNTRY', 'SALES']
sell_per_country
# Out:
#         COUNTRY       SALES
# 0     Australia   302880.96
# 1       Austria   111694.45
# 2       Belgium    33877.63
# 3        Canada    77911.44
# 4       Denmark   115478.71
# 5       Finland   128762.33
# 6        France   452240.70
# 7       Germany    86771.08
# 8       Ireland    19010.01
# 9         Italy   171407.92
# 10        Japan    73865.81
# 11       Norway   139702.53
# 12  Philippines    29227.16
# 13    Singapore   140605.82
# 14        Spain   394806.18
# 15       Sweden   107447.83
# 16  Switzerland    52535.67
# 17           UK   169166.30
# 18          USA  1616941.11

# %%
sell_per_country = sell_per_country.sort_values(by='SALES')
sell = sell_per_country.copy()
sell_per_country = sell_per_country.tail()

# %%
fig, ax = plt.subplots()

ax.bar(sell_per_country['COUNTRY'], sell_per_country['SALES'], width=1, edgecolor="white", linewidth=0.7)
ax.set_title('Top 5 most sales country');

# %%
sell_per_country.reset_index()
# Out:
#    index    COUNTRY       SALES
# 0      9      Italy   171407.92
# 1      0  Australia   302880.96
# 2     14      Spain   394806.18
# 3      6     France   452240.70
# 4     18        USA  1616941.11

# %%
sell.reset_index()
# Out:
#     index      COUNTRY       SALES
# 0       8      Ireland    19010.01
# 1      12  Philippines    29227.16
# 2       2      Belgium    33877.63
# 3      16  Switzerland    52535.67
# 4      10        Japan    73865.81
# 5       3       Canada    77911.44
# 6       7      Germany    86771.08
# 7      15       Sweden   107447.83
# 8       1      Austria   111694.45
# 9       4      Denmark   115478.71
# 10      5      Finland   128762.33
# 11     11       Norway   139702.53
# 12     13    Singapore   140605.82
# 13     17           UK   169166.30
# 14      9        Italy   171407.92
# 15      0    Australia   302880.96
# 16     14        Spain   394806.18
# 17      6       France   452240.70
# 18     18          USA  1616941.11

# %%
sell = sell.value_counts()

# %%
fig, ax = plt.subplots(figsize=(10,10))
ax.set_title('Top países compradores')
plt.pie(sell, labels=sell.index,startangle=45);

# %%
df
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6  3746.70
# 4          10159               49     100.00               14  5205.27
# ..           ...              ...        ...              ...      ...
# 995        10185               28     100.00                9  3442.04
# 996        10196               49     100.00                1  6893.81
# 997        10208               24     100.00                9  2622.48
# 998        10221               33     100.00                3  4417.38
# 999        10232               22     100.00                6  3606.02
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID   PRODUCTLINE  MSRP PRODUCTCODE  \
# 0   2003-02-24  Shipped       1         2   Motorcycles    95    S10_1678
# 1   2003-05-07  Shipped       2         5   Motorcycles    95    S10_1678
# 2   2003-07-01  Shipped       3         7   Motorcycles    95    S10_1678
# 3   2003-08-25  Shipped       3         8   Motorcycles    95    S10_1678
# 4   2003-10-10  Shipped       4        10   Motorcycles    95    S10_1678
# ..         ...      ...     ...       ...           ...   ...         ...
# 995 2003-11-14  Shipped       4        11  Vintage Cars   136    S18_3140
# 996 2003-11-26  Shipped       4        11  Vintage Cars   136    S18_3140
# 997 2004-01-02  Shipped       1         1  Vintage Cars   136    S18_3140
# 998 2004-02-18  Shipped       1         2  Vintage Cars   136    S18_3140
# 999 2004-03-20  Shipped       1         3  Vintage Cars   136    S18_3140
#
#                  CUSTOMERNAME             PHONE  \
# 0           Land of Toys Inc.        2125557818
# 1          Reims Collectables        26.47.1555
# 2             Lyon Souveniers  +33 1 46 62 7555
# 3           Toys4GrownUps.com        6265557265
# 4    Corporate Gift Ideas Co.        6505551386
# ..                        ...               ...
# 995       Mini Creations Ltd.        5085559555
# 996          Super Scale Inc.        2035559545
# 997    Saveley & Henriot, Co.        78.32.5555
# 998                Petit Auto      (02) 5554 67
# 999         giftsbymail.co.uk    (198) 555-8888
#
#                       ADDRESSLINE1           CITY          STATE POSTALCODE  \
# 0          897 Long Airport Avenue            NYC             NY      10022
# 1               59 rue de l'Abbaye          Reims            NaN      51100
# 2    27 rue du Colonel Pierre Avia          Paris            NaN      75508
# 3               78934 Hillside Dr.       Pasadena             CA      90003
# 4                  7734 Strong St.  San Francisco             CA        NaN
# ..                             ...            ...            ...        ...
# 995              4575 Hillside Dr.    New Bedford             MA      50553
# 996       567 North Pendale Street      New Haven             CT      97823
# 997             2, rue du Commerce           Lyon            NaN      69004
# 998            Rue Joseph-Bens 532      Bruxelles            NaN     B-1180
# 999      Garden House Crowther Way          Cowes  Isle of Wight   PO31 7PJ
#
#      COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  year
# 0        USA       NaN              Yu             Kwai    Small  2003
# 1     France      EMEA         Henriot             Paul    Small  2003
# 2     France      EMEA        Da Cunha           Daniel   Medium  2003
# 3        USA       NaN           Young            Julie   Medium  2003
# 4        USA       NaN           Brown            Julie   Medium  2003
# ..       ...       ...             ...              ...      ...   ...
# 995      USA       NaN             Tam           Wing C   Medium  2003
# 996      USA       NaN          Murphy           Leslie   Medium  2003
# 997   France      EMEA         Saveley             Mary    Small  2004
# 998  Belgium      EMEA           Dewey        Catherine   Medium  2004
# 999       UK      EMEA         Bennett            Helen   Medium  2004
#
# [1000 rows x 24 columns]

# %%
import numpy as np

# %%
# x = np.linspace(0, 2, 100)  # Sample data.
# fig, ax = plt.subplots(figsize=(10,5))
# ax.plot(x, x, label='normal')
# ax.plot(x, x**2, label='quadrado')
# ax.plot(x, x/10, label='fração')
# ax.plot(x ,x*3, label='x3')
# ax.set_xlabel('x label')  # Add an x-label to the Axes.
# ax.set_ylabel('y label')  # Add a y-label to the Axes.
# ax.legend()

# %%
df.head()
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0        10107               30      95.70                2  2871.00
# 1        10121               34      81.35                5  2765.90
# 2        10134               41      94.74                2  3884.34
# 3        10145               45      83.26                6  3746.70
# 4        10159               49     100.00               14  5205.27
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0 2003-02-24  Shipped       1         2  Motorcycles    95    S10_1678
# 1 2003-05-07  Shipped       2         5  Motorcycles    95    S10_1678
# 2 2003-07-01  Shipped       3         7  Motorcycles    95    S10_1678
# 3 2003-08-25  Shipped       3         8  Motorcycles    95    S10_1678
# 4 2003-10-10  Shipped       4        10  Motorcycles    95    S10_1678
#
#                CUSTOMERNAME             PHONE                   ADDRESSLINE1  \
# 0         Land of Toys Inc.        2125557818        897 Long Airport Avenue
# 1        Reims Collectables        26.47.1555             59 rue de l'Abbaye
# 2           Lyon Souveniers  +33 1 46 62 7555  27 rue du Colonel Pierre Avia
# 3         Toys4GrownUps.com        6265557265             78934 Hillside Dr.
# 4  Corporate Gift Ideas Co.        6505551386                7734 Strong St.
#
#             CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0            NYC    NY      10022     USA       NaN              Yu
# 1          Reims   NaN      51100  France      EMEA         Henriot
# 2          Paris   NaN      75508  France      EMEA        Da Cunha
# 3       Pasadena    CA      90003     USA       NaN           Young
# 4  San Francisco    CA        NaN     USA       NaN           Brown
#
#   CONTACTFIRSTNAME DEALSIZE  year
# 0             Kwai    Small  2003
# 1             Paul    Small  2003
# 2           Daniel   Medium  2003
# 3            Julie   Medium  2003
# 4            Julie   Medium  2003

# %%
S10_1678 = df.loc[df['PRODUCTCODE'] == 'S10_1678']
fig, ax = plt.subplots(figsize=(10,4))
plt.scatter(S10_1678['QUANTITYORDERED'],np.linspace(0,1,26))
ax.grid()
ax.set_title('qnt de produtos S10_1678 comprados por venda')
# Out:
# Text(0.5, 1.0, 'qnt de produtos S10_1678 comprados por venda')

# %%
df
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6  3746.70
# 4          10159               49     100.00               14  5205.27
# ..           ...              ...        ...              ...      ...
# 995        10185               28     100.00                9  3442.04
# 996        10196               49     100.00                1  6893.81
# 997        10208               24     100.00                9  2622.48
# 998        10221               33     100.00                3  4417.38
# 999        10232               22     100.00                6  3606.02
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID   PRODUCTLINE  MSRP PRODUCTCODE  \
# 0   2003-02-24  Shipped       1         2   Motorcycles    95    S10_1678
# 1   2003-05-07  Shipped       2         5   Motorcycles    95    S10_1678
# 2   2003-07-01  Shipped       3         7   Motorcycles    95    S10_1678
# 3   2003-08-25  Shipped       3         8   Motorcycles    95    S10_1678
# 4   2003-10-10  Shipped       4        10   Motorcycles    95    S10_1678
# ..         ...      ...     ...       ...           ...   ...         ...
# 995 2003-11-14  Shipped       4        11  Vintage Cars   136    S18_3140
# 996 2003-11-26  Shipped       4        11  Vintage Cars   136    S18_3140
# 997 2004-01-02  Shipped       1         1  Vintage Cars   136    S18_3140
# 998 2004-02-18  Shipped       1         2  Vintage Cars   136    S18_3140
# 999 2004-03-20  Shipped       1         3  Vintage Cars   136    S18_3140
#
#                  CUSTOMERNAME             PHONE  \
# 0           Land of Toys Inc.        2125557818
# 1          Reims Collectables        26.47.1555
# 2             Lyon Souveniers  +33 1 46 62 7555
# 3           Toys4GrownUps.com        6265557265
# 4    Corporate Gift Ideas Co.        6505551386
# ..                        ...               ...
# 995       Mini Creations Ltd.        5085559555
# 996          Super Scale Inc.        2035559545
# 997    Saveley & Henriot, Co.        78.32.5555
# 998                Petit Auto      (02) 5554 67
# 999         giftsbymail.co.uk    (198) 555-8888
#
#                       ADDRESSLINE1           CITY          STATE POSTALCODE  \
# 0          897 Long Airport Avenue            NYC             NY      10022
# 1               59 rue de l'Abbaye          Reims            NaN      51100
# 2    27 rue du Colonel Pierre Avia          Paris            NaN      75508
# 3               78934 Hillside Dr.       Pasadena             CA      90003
# 4                  7734 Strong St.  San Francisco             CA        NaN
# ..                             ...            ...            ...        ...
# 995              4575 Hillside Dr.    New Bedford             MA      50553
# 996       567 North Pendale Street      New Haven             CT      97823
# 997             2, rue du Commerce           Lyon            NaN      69004
# 998            Rue Joseph-Bens 532      Bruxelles            NaN     B-1180
# 999      Garden House Crowther Way          Cowes  Isle of Wight   PO31 7PJ
#
#      COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME DEALSIZE  year
# 0        USA       NaN              Yu             Kwai    Small  2003
# 1     France      EMEA         Henriot             Paul    Small  2003
# 2     France      EMEA        Da Cunha           Daniel   Medium  2003
# 3        USA       NaN           Young            Julie   Medium  2003
# 4        USA       NaN           Brown            Julie   Medium  2003
# ..       ...       ...             ...              ...      ...   ...
# 995      USA       NaN             Tam           Wing C   Medium  2003
# 996      USA       NaN          Murphy           Leslie   Medium  2003
# 997   France      EMEA         Saveley             Mary    Small  2004
# 998  Belgium      EMEA           Dewey        Catherine   Medium  2004
# 999       UK      EMEA         Bennett            Helen   Medium  2004
#
# [1000 rows x 24 columns]

# %%
df_2 = df.drop(['ADDRESSLINE1','PHONE'], axis=1)

# %%
mapeamento_personalizado = {'Large': 3, 'Medium': 2, 'Small': 1}

# Aplicar o mapeamento à coluna 'DEALSIZE'
df_2['DEALSIZE'] = df_2['DEALSIZE'].map(mapeamento_personalizado)

# %%
df_2
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER    SALES  \
# 0          10107               30      95.70                2  2871.00
# 1          10121               34      81.35                5  2765.90
# 2          10134               41      94.74                2  3884.34
# 3          10145               45      83.26                6  3746.70
# 4          10159               49     100.00               14  5205.27
# ..           ...              ...        ...              ...      ...
# 995        10185               28     100.00                9  3442.04
# 996        10196               49     100.00                1  6893.81
# 997        10208               24     100.00                9  2622.48
# 998        10221               33     100.00                3  4417.38
# 999        10232               22     100.00                6  3606.02
#
#      ORDERDATE   STATUS  QTR_ID  MONTH_ID   PRODUCTLINE  MSRP PRODUCTCODE  \
# 0   2003-02-24  Shipped       1         2   Motorcycles    95    S10_1678
# 1   2003-05-07  Shipped       2         5   Motorcycles    95    S10_1678
# 2   2003-07-01  Shipped       3         7   Motorcycles    95    S10_1678
# 3   2003-08-25  Shipped       3         8   Motorcycles    95    S10_1678
# 4   2003-10-10  Shipped       4        10   Motorcycles    95    S10_1678
# ..         ...      ...     ...       ...           ...   ...         ...
# 995 2003-11-14  Shipped       4        11  Vintage Cars   136    S18_3140
# 996 2003-11-26  Shipped       4        11  Vintage Cars   136    S18_3140
# 997 2004-01-02  Shipped       1         1  Vintage Cars   136    S18_3140
# 998 2004-02-18  Shipped       1         2  Vintage Cars   136    S18_3140
# 999 2004-03-20  Shipped       1         3  Vintage Cars   136    S18_3140
#
#                  CUSTOMERNAME           CITY          STATE POSTALCODE  \
# 0           Land of Toys Inc.            NYC             NY      10022
# 1          Reims Collectables          Reims            NaN      51100
# 2             Lyon Souveniers          Paris            NaN      75508
# 3           Toys4GrownUps.com       Pasadena             CA      90003
# 4    Corporate Gift Ideas Co.  San Francisco             CA        NaN
# ..                        ...            ...            ...        ...
# 995       Mini Creations Ltd.    New Bedford             MA      50553
# 996          Super Scale Inc.      New Haven             CT      97823
# 997    Saveley & Henriot, Co.           Lyon            NaN      69004
# 998                Petit Auto      Bruxelles            NaN     B-1180
# 999         giftsbymail.co.uk          Cowes  Isle of Wight   PO31 7PJ
#
#      COUNTRY TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  DEALSIZE  year
# 0        USA       NaN              Yu             Kwai         1  2003
# 1     France      EMEA         Henriot             Paul         1  2003
# 2     France      EMEA        Da Cunha           Daniel         2  2003
# 3        USA       NaN           Young            Julie         2  2003
# 4        USA       NaN           Brown            Julie         2  2003
# ..       ...       ...             ...              ...       ...   ...
# 995      USA       NaN             Tam           Wing C         2  2003
# 996      USA       NaN          Murphy           Leslie         2  2003
# 997   France      EMEA         Saveley             Mary         1  2004
# 998  Belgium      EMEA           Dewey        Catherine         2  2004
# 999       UK      EMEA         Bennett            Helen         2  2004
#
# [1000 rows x 22 columns]

# %%
graph_df = df_2.groupby(by='ORDERDATE').agg({'QUANTITYORDERED': 'sum'}).reset_index()

# %%
graph_df
# Out:
#      ORDERDATE  QUANTITYORDERED
# 0   2003-01-06               80
# 1   2003-01-09               51
# 2   2003-01-10               80
# 3   2003-01-29              239
# 4   2003-01-31              128
# ..         ...              ...
# 217 2005-05-13              224
# 218 2005-05-17              291
# 219 2005-05-29              153
# 220 2005-05-30              138
# 221 2005-05-31              309
#
# [222 rows x 2 columns]

# %%
fig, axes = plt.subplots(1,2,figsize=(20,5))
axes[0].plot(graph_df['ORDERDATE'], graph_df['QUANTITYORDERED'], drawstyle='steps-mid', color='g', label='Vendas', linestyle='-', marker='o')
axes[0].set_title('Vendas por Data')
axes[0].set_xlabel('Data')
axes[0].set_ylabel('Vendas')
axes[0].grid()
axes[0].legend()

axes[0].set_xticklabels([x.strftime('%Y-%m-%d') for x in graph_df['ORDERDATE']], rotation=45)


axes[1].scatter(graph_df['ORDERDATE'], graph_df['QUANTITYORDERED'], color='blue', label='Dispersão')
axes[1].set_title('Dispersão de Vendas')
axes[1].set_xlabel('Data')
axes[1].set_ylabel('Vendas')
axes[1].grid()
axes[1].legend()

axes[1].set_xticklabels([x.strftime('%Y-%m-%d') for x in graph_df['ORDERDATE']], rotation=45)

plt.tight_layout()

plt.savefig('vendaspordata.png')
plt.show()
# Out:
# C:\Users\Kaio\AppData\Local\Temp\ipykernel_2472\4140533996.py:9: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[0].set_xticklabels([x.strftime('%Y-%m-%d') for x in graph_df['ORDERDATE']], rotation=45)
# C:\Users\Kaio\AppData\Local\Temp\ipykernel_2472\4140533996.py:19: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   axes[1].set_xticklabels([x.strftime('%Y-%m-%d') for x in graph_df['ORDERDATE']], rotation=45)

# %%
graph_df = pd.DataFrame(graph_df)

# %%
graph_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 2 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   ORDERDATE        222 non-null    datetime64[ns]
#  1   QUANTITYORDERED  222 non-null    int64
# dtypes: datetime64[ns](1), int64(1)
# memory usage: 3.6 KB

# %%
graph_df
# Out:
#      ORDERDATE  QUANTITYORDERED
# 0   2003-01-06               80
# 1   2003-01-09               51
# 2   2003-01-10               80
# 3   2003-01-29              239
# 4   2003-01-31              128
# ..         ...              ...
# 217 2005-05-13              224
# 218 2005-05-17              291
# 219 2005-05-29              153
# 220 2005-05-30              138
# 221 2005-05-31              309
#
# [222 rows x 2 columns]

# %%
df_2.isna().sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# CITY                  0
# STATE               507
# POSTALCODE           41
# COUNTRY               0
# TERRITORY           395
# CONTACTLASTNAME       0
# CONTACTFIRSTNAME      0
# DEALSIZE              0
# year                  0
# dtype: int64

# %%
df_2['STATE'].fillna('no estate', inplace=True)
# Out:
# C:\Users\Kaio\AppData\Local\Temp\ipykernel_2472\1298263906.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2['STATE'].fillna('no estate', inplace=True)

# %%
df_2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 22 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   ORDERNUMBER       1000 non-null   int64
#  1   QUANTITYORDERED   1000 non-null   int64
#  2   PRICEEACH         1000 non-null   float64
#  3   ORDERLINENUMBER   1000 non-null   int64
#  4   SALES             1000 non-null   float64
#  5   ORDERDATE         1000 non-null   datetime64[ns]
#  6   STATUS            1000 non-null   object
#  7   QTR_ID            1000 non-null   int64
#  8   MONTH_ID          1000 non-null   int64
#  9   PRODUCTLINE       1000 non-null   object
#  10  MSRP              1000 non-null   int64
#  11  PRODUCTCODE       1000 non-null   object
#  12  CUSTOMERNAME      1000 non-null   object
#  13  CITY              1000 non-null   object
#  14  STATE             1000 non-null   object
#  15  POSTALCODE        959 non-null    object
#  16  COUNTRY           1000 non-null   object
#  17  TERRITORY         605 non-null    object
#  18  CONTACTLASTNAME   1000 non-null   object
#  19  CONTACTFIRSTNAME  1000 non-null   object
#  20  DEALSIZE          1000 non-null   int64
#  21  year              1000 non-null   int32
# dtypes: datetime64[ns](1), float64(2), int32(1), int64(7), object(11)
# memory usage: 168.1+ KB

# %%
df_2.head(1)
# Out:
#    ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES  \
# 0        10107               30       95.7                2  2871.0
#
#    ORDERDATE   STATUS  QTR_ID  MONTH_ID  PRODUCTLINE  MSRP PRODUCTCODE  \
# 0 2003-02-24  Shipped       1         2  Motorcycles    95    S10_1678
#
#         CUSTOMERNAME CITY STATE POSTALCODE COUNTRY TERRITORY CONTACTLASTNAME  \
# 0  Land of Toys Inc.  NYC    NY      10022     USA       NaN              Yu
#
#   CONTACTFIRSTNAME  DEALSIZE  year
# 0             Kwai         1  2003

# %%
df_2.isna().sum()
# Out:
# ORDERNUMBER           0
# QUANTITYORDERED       0
# PRICEEACH             0
# ORDERLINENUMBER       0
# SALES                 0
# ORDERDATE             0
# STATUS                0
# QTR_ID                0
# MONTH_ID              0
# PRODUCTLINE           0
# MSRP                  0
# PRODUCTCODE           0
# CUSTOMERNAME          0
# CITY                  0
# STATE                 0
# POSTALCODE           41
# COUNTRY               0
# TERRITORY           395
# CONTACTLASTNAME       0
# CONTACTFIRSTNAME      0
# DEALSIZE              0
# year                  0
# dtype: int64

# %%
df_2['POSTALCODE'].dropna(axis=0, inplace=True)

# %%
df_2['TERRITORY'].fillna('no register', inplace=True)
# Out:
# C:\Users\Kaio\AppData\Local\Temp\ipykernel_2472\1943234511.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df_2['TERRITORY'].fillna('no register', inplace=True)

# %%
df_2.drop('POSTALCODE', axis=1, inplace=True)

# %%
df_2.isna().sum()
# Out:
# ORDERNUMBER         0
# QUANTITYORDERED     0
# PRICEEACH           0
# ORDERLINENUMBER     0
# SALES               0
# ORDERDATE           0
# STATUS              0
# QTR_ID              0
# MONTH_ID            0
# PRODUCTLINE         0
# MSRP                0
# PRODUCTCODE         0
# CUSTOMERNAME        0
# CITY                0
# STATE               0
# COUNTRY             0
# TERRITORY           0
# CONTACTLASTNAME     0
# CONTACTFIRSTNAME    0
# DEALSIZE            0
# year                0
# dtype: int64

# %%
df_2.head(5)
df_2 = df_2.sort_values(by='ORDERDATE').reset_index()

# %%
df_2.drop('index', axis=1, inplace=True)

# %%
df_2.tail()
# Out:
#      ORDERNUMBER  QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER     SALES  \
# 995        10425               19      49.22               10    935.18
# 996        10425               38      99.41                7   3777.58
# 997        10424               54     100.00                5   7182.00
# 998        10425               33     100.00                4   4692.60
# 999        10424               50     100.00                6  12001.00
#
#      ORDERDATE      STATUS  QTR_ID  MONTH_ID       PRODUCTLINE  MSRP  \
# 995 2005-05-31  In Process       2         5  Trucks and Buses    60
# 996 2005-05-31  In Process       2         5  Trucks and Buses   122
# 997 2005-05-31  In Process       2         5  Trucks and Buses   116
# 998 2005-05-31  In Process       2         5  Trucks and Buses   118
# 999 2005-05-31  In Process       2         5      Classic Cars   214
#
#     PRODUCTCODE           CUSTOMERNAME    CITY      STATE COUNTRY TERRITORY  \
# 995    S18_2432      La Rochelle Gifts  Nantes  no estate  France      EMEA
# 996    S18_2319      La Rochelle Gifts  Nantes  no estate  France      EMEA
# 997    S18_1097  Euro Shopping Channel  Madrid  no estate   Spain      EMEA
# 998    S12_4473      La Rochelle Gifts  Nantes  no estate  France      EMEA
# 999    S10_1949  Euro Shopping Channel  Madrid  no estate   Spain      EMEA
#
#     CONTACTLASTNAME CONTACTFIRSTNAME  DEALSIZE  year
# 995         Labrune           Janine         1  2005
# 996         Labrune           Janine         2  2005
# 997          Freyre            Diego         3  2005
# 998         Labrune           Janine         2  2005
# 999          Freyre            Diego         3  2005

# %%
df_2.drop('ORDERNUMBER', axis=1, inplace=True)

# %%
df_2['ORDERDATE'] = pd.to_datetime(df_2['ORDERDATE'])
df_2['Year'] = df_2['ORDERDATE'].dt.year
df_2['Month'] = df_2['ORDERDATE'].dt.month
df_2['Day'] = df_2['ORDERDATE'].dt.day
df_2.drop(['ORDERDATE', 'year'], axis=1, inplace=True)

# %%
df_2.head(1)
# Out:
#    QUANTITYORDERED  PRICEEACH  ORDERLINENUMBER   SALES   STATUS  QTR_ID  \
# 0               30      100.0                3  5151.0  Shipped       1
#
#    MONTH_ID   PRODUCTLINE  MSRP PRODUCTCODE                  CUSTOMERNAME  \
# 0         1  Vintage Cars   170    S18_1749  Online Diecast Creations Co.
#
#      CITY STATE COUNTRY    TERRITORY CONTACTLASTNAME CONTACTFIRSTNAME  \
# 0  Nashua    NH     USA  no register           Young          Valarie
#
#    DEALSIZE  Year  Month  Day
# 0         2  2003      1    6

# %%
y = df_2.iloc[:, 0].values
x = df_2.iloc[:, 1:].values

# %%
# y

# %%
x[0]
# Out:
# array([100.0, 3, 5151.0, 'Shipped', 1, 1, 'Vintage Cars', 170, 'S18_1749',
#        'Online Diecast Creations Co.', 'Nashua', 'NH', 'USA',
#        'no register', 'Young', 'Valarie', 2, 2003, 1, 6], dtype=object)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.compose import ColumnTransformer


onehotencoder_x= ColumnTransformer(transformers=[("OneHot", OneHotEncoder(), [3,6,8,9,10,11,12,13,14,15])], remainder="passthrough")
x = onehotencoder_x.fit_transform(x).toarray()

# %%
x,y
# Out:
# (array([[0.000e+00, 0.000e+00, 0.000e+00, ..., 2.003e+03, 1.000e+00,
#          6.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 2.003e+03, 1.000e+00,
#          6.000e+00],
#         [0.000e+00, 0.000e+00, 0.000e+00, ..., 2.003e+03, 1.000e+00,
#          9.000e+00],
#         ...,
#         [0.000e+00, 0.000e+00, 1.000e+00, ..., 2.005e+03, 5.000e+00,
#          3.100e+01],
#         [0.000e+00, 0.000e+00, 1.000e+00, ..., 2.005e+03, 5.000e+00,
#          3.100e+01],
#         [0.000e+00, 0.000e+00, 1.000e+00, ..., 2.005e+03, 5.000e+00,
#          3.100e+01]]),
#  array([30, 50, 25, 26, 39, 41, 26, 35, 27, 42, 27, 22, 25, 35, 41, 24, 29,
#         34, 41, 29, 50, 22, 36, 41, 34, 29, 21, 27, 39, 30, 33, 39, 38, 45,
#         36, 26, 26, 38, 31, 32, 33, 37, 42, 23, 29, 48, 28, 43, 33, 49, 21,
#         31, 39, 45, 46, 46, 26, 39, 43, 33, 46, 21, 43, 29, 46, 46, 29, 50,
#         34, 43, 32, 34, 37, 42, 20, 31, 46, 26, 32, 34, 42, 42, 21, 38, 43,
#         30, 38, 46, 42, 22, 21, 31, 45, 42, 45, 46, 24, 46, 41, 33, 21, 40,
#         49, 31, 20, 41, 27, 30, 48, 42, 48, 24, 29, 25, 36, 37, 44, 31, 20,
#         46, 49, 41, 20, 32, 37, 46, 26, 38, 21, 47, 39, 46, 33, 47, 33, 49,
#         32, 46, 30, 30, 49, 45, 37, 33, 33, 48, 26, 31, 21, 47, 25, 27, 23,
#         33, 23, 50, 34, 24, 30, 34, 30, 45, 20, 26, 47, 30, 39, 49, 43, 24,
#         42, 49, 31, 20, 29, 33, 41, 22, 23, 32, 22, 47, 37, 38, 44, 32, 43,
#         24, 49, 37, 38, 22, 42, 41, 46, 38, 50, 28, 48, 23, 43, 45, 48, 38,
#         27, 29, 48, 48, 31, 21, 40, 43, 21, 36, 49, 29, 48, 31, 34, 46, 27,
#         44, 44, 46, 43, 20, 46, 21, 27, 36, 20, 35, 41, 47, 36, 30, 31, 35,
#         26, 43, 42, 24, 35, 31, 28, 22, 39, 48, 46, 43, 48, 41, 48, 20, 34,
#         33, 33, 47, 50, 26, 23, 42, 24, 41, 29, 25, 42, 41, 40, 25, 44, 44,
#         22, 27, 21, 20, 21, 32, 36, 27, 20, 42, 28, 38, 37, 41, 28, 23, 39,
#         21, 22, 32, 37, 32, 43, 21, 46, 28, 44, 33, 46, 26, 38, 48, 32, 45,
#         28, 40, 21, 30, 45, 27, 38, 29, 47, 22, 28, 44, 23, 21, 42, 22, 28,
#         46, 24, 42, 26, 38, 21, 27, 49, 35, 45, 45, 24, 46, 49, 47, 38, 42,
#         22, 30, 49, 24, 25, 20, 45, 27, 40, 44, 33, 38, 26, 47, 20, 23, 42,
#         40, 48, 36, 37, 34, 47, 28, 30, 28, 37, 31, 34, 43, 44, 24, 26, 46,
#         20, 39, 28, 40, 23, 34, 31, 50, 41, 41, 28, 36, 41, 29, 20, 33, 39,
#         40, 38, 27, 50, 30, 21, 27, 46, 35, 49, 33, 31, 49, 43, 48, 35, 43,
#         48, 32, 27, 30, 33, 49, 49, 49, 47, 47, 37, 28, 49, 43, 47, 27, 32,
#         37, 21, 25, 38, 24, 24, 46, 31, 28, 26, 29, 25, 29, 45, 24, 32, 31,
#         50, 25, 36, 26, 28, 49, 43, 42, 49, 22, 24, 23, 22, 23, 39, 32, 28,
#         20, 29, 21, 46, 37, 41, 44, 21, 33, 41, 47, 24, 30, 20, 40, 43, 29,
#         28, 34, 29, 38, 25, 22, 27, 44, 46, 40, 30, 21, 20, 27, 45, 44, 29,
#         43, 46, 28, 33, 41, 24, 22, 37, 24, 25, 23, 26, 24, 34, 29, 49, 50,
#         37, 46, 30, 41, 41, 30, 26, 34, 32, 27, 49, 32, 33, 41, 48, 40, 34,
#         34, 49, 20, 22, 44, 40, 21, 36, 33, 35, 32, 38, 21, 32, 43, 31, 28,
#         31, 50, 25, 27, 50, 39, 35, 34, 30, 41, 35, 22, 36, 45, 37, 50, 47,
#         38, 43, 28, 29, 23, 34, 39, 29, 34, 25, 26, 27, 50, 22, 46, 29, 24,
#         43, 37, 25, 48, 29, 44, 41, 21, 24, 27, 41, 25, 23, 45, 31, 49, 47,
#         20, 27, 36, 24, 44, 45, 21, 44, 41, 41, 23, 28, 31, 32, 20, 24, 43,
#         38, 26, 23, 37, 41, 37, 21, 30, 47, 41, 41, 26, 24, 45, 46, 24, 21,
#         36, 25, 39, 32, 29, 23, 24, 46, 37, 46, 39, 24, 26, 47, 37, 46, 24,
#         20, 41, 38, 27, 38, 36, 22, 34, 20, 39, 31, 31, 27, 34, 20, 41, 26,
#         34, 25, 29, 24, 49, 37, 43, 33, 20, 24, 43, 30, 37, 32, 48, 38, 48,
#         35, 31, 25, 25, 34, 36, 29, 38, 40, 21, 42, 46, 45, 47, 48, 27, 33,
#         21, 31, 46, 45, 42, 37, 35, 31, 38, 30, 50, 40, 35, 22, 46, 41, 27,
#         27, 33, 25, 41, 44, 37, 48, 41, 24, 43, 36, 27, 47, 33, 26, 42, 47,
#         24, 25, 45, 25, 29, 26, 41, 46, 38, 42, 20, 24, 39, 33, 44, 46, 40,
#         27, 46, 44, 30, 38, 24, 35, 26, 26, 33, 26, 31, 29, 46, 26, 34, 33,
#         33, 49, 49, 38, 25, 41, 28, 39, 30, 40, 27, 55, 44, 40, 41, 55, 45,
#         55, 22, 36, 36, 25, 30, 45, 40, 30, 27, 21, 42, 34, 48, 42, 21, 45,
#         29, 50, 38, 38, 48, 26, 26, 43, 39, 27, 30, 27, 22, 50, 43, 29, 20,
#         49, 49, 20, 43, 41, 44, 42, 32, 39, 49, 41, 49, 42, 48, 26, 20, 23,
#         22, 22, 46, 22, 34, 33, 34, 30, 49, 34, 32, 27, 45, 37, 49, 21, 27,
#         42, 22, 41, 44, 35, 22, 49, 32, 28, 32, 25, 49, 40, 34, 28, 39, 22,
#         39, 22, 42, 22, 21, 45, 49, 35, 31, 36, 50, 35, 24, 27, 29, 34, 39,
#         40, 27, 21, 41, 25, 35, 48, 32, 35, 34, 36, 37, 34, 40, 25, 20, 37,
#         27, 34, 21, 37, 25, 25, 47, 26, 36, 39, 49, 21, 44, 42, 50, 36, 31,
#         26, 34, 24, 35, 39, 32, 29, 44, 37, 42, 37, 29, 33, 32, 33, 28, 33,
#         34, 64, 34, 30, 42, 55, 45, 24, 66, 66, 61, 97, 61, 48, 41, 76, 42,
#         59,  6, 40, 27, 27, 23, 47, 54, 56, 41, 47, 36, 22, 44, 19, 24, 15,
#         36, 45, 56, 66, 21, 55, 39, 34, 10, 12, 37, 32, 34, 38, 37, 45, 36,
#         35, 25, 10, 31, 21, 51, 49, 28, 38, 19, 38, 54, 33, 50],
#        dtype=int64))

# %%
x.shape
# Out:
# (1000, 415)

# %%
# for valor, codigo in zip(label_encoder.classes_, label_encoder.transform(label_encoder.classes_)):
#     print(f"{valor}: {codigo}")

# %%
from sklearn.preprocessing import StandardScaler
scaler= StandardScaler()
x = scaler.fit_transform(x)

# %%
x
# Out:
# array([[-0.12751534, -0.08396038, -0.13150665, ..., -1.12962632,
#         -1.66741985, -0.93862358],
#        [-0.12751534, -0.08396038, -0.13150665, ..., -1.12962632,
#         -1.66741985, -0.93862358],
#        [-0.12751534, -0.08396038, -0.13150665, ..., -1.12962632,
#         -1.66741985, -0.59421669],
#        ...,
#        [-0.12751534, -0.08396038,  7.60417842, ...,  1.70506958,
#         -0.57653346,  1.93143385],
#        [-0.12751534, -0.08396038,  7.60417842, ...,  1.70506958,
#         -0.57653346,  1.93143385],
#        [-0.12751534, -0.08396038,  7.60417842, ...,  1.70506958,
#         -0.57653346,  1.93143385]])

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.25, random_state=0)

# %%
# from sklearn.model_selection import cross_val_score
# from sklearn.linear_model import LinearRegression
# from sklearn.ensemble import RandomForestRegressor
# from sklearn.svm import SVR
# from sklearn.neighbors import KNeighborsRegressor
# from sklearn.tree import DecisionTreeRegressor

# # Defina os modelos que você deseja testar
# models = {
#     'Linear Regression': LinearRegression(),
#     'Random Forest': RandomForestRegressor(),
#     'Support Vector Machine': SVR(),
#     'K-Nearest Neighbors': KNeighborsRegressor(),
#     'Decision Tree': DecisionTreeRegressor()
# }

# # Avalie cada modelo usando validação cruzada
# for name, model in models.items():
#     scores = cross_val_score(model, X_train, y_train, cv=5, scoring='r2')
#     print(f'{name}: Média R^2 = {scores.mean()}, Desvio Padrão R^2 = {scores.std()}')

# %% [markdown]
# Melhores parâmetros encontrados:
# {'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 5, 'n_estimators': 100}
# Coeficiente de Determinação (R²) nos dados de teste: 0.7609357107495814

# %%
from sklearn.metrics import r2_score
random_forest = RandomForestRegressor(max_depth=None, min_samples_leaf=4,min_samples_split=5,n_estimators=100)
random_forest.fit(X_train, y_train)
previsoes = random_forest.predict(X_test)
r2 = r2_score(y_test, previsoes)
print(f'Coeficiente de Determinação (R²) nos dados de teste: {r2}')
# Out:
# Coeficiente de Determinação (R²) nos dados de teste: 0.7648805971066159

# %%
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestRegressor

# Instancia o modelo de Random Forest com os melhores parâmetros encontrados
estimator = RandomForestRegressor(max_depth=None, min_samples_leaf=4, min_samples_split=5, n_estimators=100)

# Instancia o seletor de características
seletor = SelectFromModel(estimator)

# Treina o seletor com os dados de treinamento
X_train = seletor.fit_transform(X_train, y_train)

# Aplica a seleção de características nos dados de teste
X_test = seletor.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[770], line 25
#      22 else:
#      23     seletor = SelectFromModel(model, importance_getter='mean')  # Defina um importance_getter padrão para outros modelos
# ---> 25 X_train_selecionado = seletor.fit_transform(X_train, y_train)
#      26 X_test_selecionado = seletor.transform(X_test)
#      28 scores = cross_val_score(model, X_train_selecionado, y_train, cv=5, scoring='r2')
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:919, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     916     return self.fit(X, **fit_params).transform(X)
#     917 else:
#     918     # fit method of arity 2 (supervised transformation)
# --> 919     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:96, in SelectorMixin.transform(self, X)
#      86 # note: we use _safe_tags instead of _get_tags because this is a
#      87 # public Mixin.
#      88 X = self._validate_data(
#      89     X,
#      90     dtype=None,
#    (...)
#      94     reset=False,
#      95 )
# ---> 96 return self._transform(X)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:100, in SelectorMixin._transform(self, X)
#      98 def _transform(self, X):
#      99     """Reduce X to the selected features."""
# --> 100     mask = self.get_support()
#     101     if not mask.any():
#     102         warnings.warn(
#     103             (
#     104                 "No features were selected: either the data is"
#    (...)
#     107             UserWarning,
#     108         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:53, in SelectorMixin.get_support(self, indices)
#      33 def get_support(self, indices=False):
#      34     """
#      35     Get a mask, or integer index, of the features selected.
#      36
#    (...)
#      51         values are indices into the input feature vector.
#      52     """
# ---> 53     mask = self._get_support_mask()
#      54     return mask if not indices else np.where(mask)[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_from_model.py:287, in SelectFromModel._get_support_mask(self)
#     281 elif max_features is not None and not isinstance(max_features, Integral):
#     282     raise ValueError(
#     283         f"`max_features` must be an integer. Got `max_features={max_features}` "
#     284         "instead."
#     285     )
# --> 287 scores = _get_feature_importances(
#     288     estimator=estimator,
#     289     getter=self.importance_getter,
#     290     transform_func="norm",
#     291     norm_order=self.norm_order,
#     292 )
#     293 threshold = _calculate_threshold(estimator, scores, self.threshold)
#     294 if self.max_features is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:226, in _get_feature_importances(estimator, getter, transform_func, norm_order)
#     223 elif not callable(getter):
#     224     raise ValueError("`importance_getter` has to be a string or `callable`")
# --> 226 importances = getter(estimator)
#     228 if transform_func is None:
#     229     return importances
#
# AttributeError: 'LinearRegression' object has no attribute 'mean'

# %%
seletor.get_feature_names_out()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[628], line 1
# ----> 1 seletor.get_feature_names_out()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:176, in SelectorMixin.get_feature_names_out(self, input_features)
#     174 check_is_fitted(self)
#     175 input_features = _check_feature_names_in(self, input_features)
# --> 176 return input_features[self.get_support()]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:53, in SelectorMixin.get_support(self, indices)
#      33 def get_support(self, indices=False):
#      34     """
#      35     Get a mask, or integer index, of the features selected.
#      36
#    (...)
#      51         values are indices into the input feature vector.
#      52     """
# ---> 53     mask = self._get_support_mask()
#      54     return mask if not indices else np.where(mask)[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_from_model.py:287, in SelectFromModel._get_support_mask(self)
#     281 elif max_features is not None and not isinstance(max_features, Integral):
#     282     raise ValueError(
#     283         f"`max_features` must be an integer. Got `max_features={max_features}` "
#     284         "instead."
#     285     )
# --> 287 scores = _get_feature_importances(
#     288     estimator=estimator,
#     289     getter=self.importance_getter,
#     290     transform_func="norm",
#     291     norm_order=self.norm_order,
#     292 )
#     293 threshold = _calculate_threshold(estimator, scores, self.threshold)
#     294 if self.max_features is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:214, in _get_feature_importances(estimator, getter, transform_func, norm_order)
#     212         getter = attrgetter("feature_importances_")
#     213     else:
# --> 214         raise ValueError(
#     215             "when `importance_getter=='auto'`, the underlying "
#     216             f"estimator {estimator.__class__.__name__} should have "
#     217             "`coef_` or `feature_importances_` attribute. Either "
#     218             "pass a fitted estimator to feature selector or call fit "
#     219             "before calling transform."
#     220         )
#     221 else:
#     222     getter = attrgetter(getter)
#
# ValueError: when `importance_getter=='auto'`, the underlying estimator SVR should have `coef_` or `feature_importances_` attribute. Either pass a fitted estimator to feature selector or call fit before calling transform.

# %%
estimator.fit(X_train_selecionado, y_train)

# Faça previsões nos dados de teste com características selecionadas
previsoes_selecionadas = estimator.predict(X_test_selecionado)

# Calcule o R² nos dados de teste com características selecionadas
r2_selecionado = r2_score(y_test, previsoes_selecionadas)

print(f'R² nos dados de teste com características selecionadas: {r2_selecionado}')
# Out:
# Modelo: Linear Regression
# Média R²: -5.928155383948626e+25
# Desvio Padrão R²: 1.1856310767897252e+26
# ----------------------
# Modelo: Random Forest
# Média R²: 0.8135638949147564
# Desvio Padrão R²: 0.043182272496333
# ----------------------
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[627], line 24
#      21 seletor = SelectFromModel(model)
#      23 # Treina o seletor com os dados de treinamento
# ---> 24 X_train_selecionado = seletor.fit_transform(X_train, y_train)
#      26 # Aplica a seleção de características nos dados de teste
#      27 X_test_selecionado = seletor.transform(X_test)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\base.py:919, in TransformerMixin.fit_transform(self, X, y, **fit_params)
#     916     return self.fit(X, **fit_params).transform(X)
#     917 else:
#     918     # fit method of arity 2 (supervised transformation)
# --> 919     return self.fit(X, y, **fit_params).transform(X)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\utils\_set_output.py:157, in _wrap_method_output.<locals>.wrapped(self, X, *args, **kwargs)
#     155 @wraps(f)
#     156 def wrapped(self, X, *args, **kwargs):
# --> 157     data_to_wrap = f(self, X, *args, **kwargs)
#     158     if isinstance(data_to_wrap, tuple):
#     159         # only wrap the first output for cross decomposition
#     160         return_tuple = (
#     161             _wrap_data_with_container(method, data_to_wrap[0], X, self),
#     162             *data_to_wrap[1:],
#     163         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:96, in SelectorMixin.transform(self, X)
#      86 # note: we use _safe_tags instead of _get_tags because this is a
#      87 # public Mixin.
#      88 X = self._validate_data(
#      89     X,
#      90     dtype=None,
#    (...)
#      94     reset=False,
#      95 )
# ---> 96 return self._transform(X)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:100, in SelectorMixin._transform(self, X)
#      98 def _transform(self, X):
#      99     """Reduce X to the selected features."""
# --> 100     mask = self.get_support()
#     101     if not mask.any():
#     102         warnings.warn(
#     103             (
#     104                 "No features were selected: either the data is"
#    (...)
#     107             UserWarning,
#     108         )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:53, in SelectorMixin.get_support(self, indices)
#      33 def get_support(self, indices=False):
#      34     """
#      35     Get a mask, or integer index, of the features selected.
#      36
#    (...)
#      51         values are indices into the input feature vector.
#      52     """
# ---> 53     mask = self._get_support_mask()
#      54     return mask if not indices else np.where(mask)[0]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_from_model.py:287, in SelectFromModel._get_support_mask(self)
#     281 elif max_features is not None and not isinstance(max_features, Integral):
#     282     raise ValueError(
#     283         f"`max_features` must be an integer. Got `max_features={max_features}` "
#     284         "instead."
#     285     )
# --> 287 scores = _get_feature_importances(
#     288     estimator=estimator,
#     289     getter=self.importance_getter,
#     290     transform_func="norm",
#     291     norm_order=self.norm_order,
#     292 )
#     293 threshold = _calculate_threshold(estimator, scores, self.threshold)
#     294 if self.max_features is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.10_qbz5n2kfra8p0\LocalCache\local-packages\Python310\site-packages\sklearn\feature_selection\_base.py:214, in _get_feature_importances(estimator, getter, transform_func, norm_order)
#     212         getter = attrgetter("feature_importances_")
#     213     else:
# --> 214         raise ValueError(
#     215             "when `importance_getter=='auto'`, the underlying "
#     216             f"estimator {estimator.__class__.__name__} should have "
#     217             "`coef_` or `feature_importances_` attribute. Either "
#     218             "pass a fitted estimator to feature selector or call fit "
#     219             "before calling transform."
#     220         )
#     221 else:
#     222     getter = attrgetter(getter)
#
# ValueError: when `importance_getter=='auto'`, the underlying estimator SVR should have `coef_` or `feature_importances_` attribute. Either pass a fitted estimator to feature selector or call fit before calling transform.
